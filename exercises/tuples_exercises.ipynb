# %% [markdown]
# # Tuples Exercises
#
# Answer quick diagnostics mentally, then solve the required tasks.

# %% [markdown]
# ## Quick Diagnostic (Brief Answers)
# - List vs Tuple: mutable vs immutable
# - `(1,2,3)[1]` -> `2`
# - `(5)` is int, `(5,)` is tuple
# - Tuple unpacking: assign multiple values in one line

# %% [markdown]
# ## Practice - Required (One Program)
# 1. Create `(10,20,30,40)`, print first, last, length
# 2. Print second element of `(5,10,15,20)`
# 3. Immutability test with `try/except` and print `Tuple is immutable`
# 4. Unpack `(100,200,300)` into 3 variables and print
# 5. Extended unpacking from `(1,2,3,4,5)` into `a` and list `b`
# 6. Mini problem: input `(x, y)` and print distance from origin

# %%
# Write one complete program for all tuple tasks here

# %% [markdown]
# ## Optional Scratch Cells

# %%
# Task 1 scratch

# %%
# Task 2 scratch

# %%
# Task 3 scratch

# %%
# Task 4 scratch

# %%
# Task 5 scratch

# %%
# Task 6 scratch
