# %% [markdown]
# # Basic Questions
#
# Practice these in order. Write your code in the empty code cells.

# %% [markdown]
# ## Practice - Level 1 (Basic)
#
# ### 1) Create variables
#
# Create:
#
# - `age = 21`
# - `height = 5.9`
# - `name = "Alex"`
# - `is_student = True`
#
# Print value and type of each.

# %%
# Write your answer here

# %% [markdown]
# ### 2) Convert values
#
# - Convert `"50"` to `int` and add `10`
# - Convert `25` to `str` and concatenate `" years"`

# %%
# Write your answer here

# %% [markdown]
# ### 3) What is the output?
#
# ```python
# x = "10"
# y = 5
# print(int(x) + y)
# ```

# %%
# Write your answer here

# %% [markdown]
# ## Practice - Level 2 (Thinking)
#
# ### 1) Input and conversion
#
# Write code to:
#
# - Ask user for a number using `input()`
# - Convert it to integer
# - Print number * 2

# %%
# Write your answer here

# %% [markdown]
# ### 2) Show truthiness
#
# Print boolean value of:
#
# - `0`
# - `1`
# - `""`
# - `"hello"`

# %%
# Write your answer here

# %% [markdown]
# ## Real-World Mini Problem
#
# ### User Age Validator
#
# Write a program to:
#
# - Ask user name
# - Ask user age (input is string)
# - Convert age to integer
# - Print:
#
# `Hello <name>, next year you will be <age+1>`

# %%
# Write your answer here
