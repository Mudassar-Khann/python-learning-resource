# %% [markdown]
# # Loops Exercises
#
# Practice these tasks carefully.

# %% [markdown]
# ## Practice - Required
#
# Write one program containing all tasks.
#
# ### Task 1 - Print 1 to 10 using `for`
#
# ### Task 2 - Print 10 to 1 using `while`
#
# ### Task 3 - Sum of first `N` numbers
#
# - Input `N`
# - Compute `1 + 2 + ... + N`
#
# ### Task 4 - `break` example
#
# - Loop from `1` to `100`
# - Stop when number is divisible by both `7` and `5`
#
# ### Task 5 - `continue` example
#
# - Print numbers `1` to `20`
# - Skip multiples of `3`
#
# ### Task 6 - Nested loop pattern
#
# Print:
#
# ```
# *
# **
# ***
# ****
# *****
# ```
#
# ### Task 7 - Real Mini Problem (Password attempts)
#
# - Correct password is `"python"`
# - Allow max 3 attempts
# - If correct: `"Access granted"`
# - Else after 3 attempts: `"Account locked"`
# - Use loop + `break`

# %%
# Write one complete program here

# %% [markdown]
# ## Optional: Solve Task by Task
#
# If needed, use the following scratch cells before writing the final single-program answer.

# %%
# Task 1 scratch

# %%
# Task 2 scratch

# %%
# Task 3 scratch

# %%
# Task 4 scratch

# %%
# Task 5 scratch

# %%
# Task 6 scratch

# %%
# Task 7 scratch
