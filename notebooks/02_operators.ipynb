# %% [markdown]
# # Operators
#
# This notebook covers Python operators:
# - Arithmetic Operators
# - Assignment Operators
# - Comparison Operators

# %% [markdown]
# ### Arithmetic Operators
#
# | Operator | Meaning             | Example | Result |
# | -------- | ------------------- | ------- | ------ |
# | `+`      | Add                 | `5+2`   | `7`    |
# | `-`      | Subtract            | `5-2`   | `3`    |
# | `*`      | Multiply            | `5*2`   | `10`   |
# | `/`      | Division (float)    | `5/2`   | `2.5`  |
# | `//`     | Floor division      | `5//2`  | `2`    |
# | `%`      | Modulus (remainder) | `5%2`   | `1`    |
# | `**`     | Power               | `2**3`  | `8`    |

# %% [markdown]
# ### Assignment Operators
#
# | Operator | Meaning               |
# | -------- | --------------------- |
# | `=`      | assign                |
# | `+=`     | add & assign          |
# | `-=`     | subtract & assign     |
# | `*=`     | multiply & assign     |
# | `/=`     | divide & assign       |
# | `//=`    | floor divide & assign |
# | `%=`     | remainder & assign    |
# | `**=`    | power & assign        |

# %%
x = 5
x = x + 5
print(x)
x = 5
# is same as 

x += 5
print(x)

# %% [markdown]
# ### Comparison Operators
#
# | Operator | Meaning          |
# | -------- | ---------------- |
# | `==`     | equal            |
# | `!=`     | not equal        |
# | `>`      | greater          |
# | `<`      | less             |
# | `>=`     | greater or equal |
# | `<=`     | less or equal    |

# %% [markdown]
# **Operator Precedence (important)**
#
# 2 + 3 * 4 = 14
# (2 + 3) * 4 = 20

# %% [markdown]
# ### Arithmetic Operators

# %% [markdown]
# | Operator | Meaning             | Example | Result |
# | -------- | ------------------- | ------- | ------ |
# | `+`      | Add                 | `5+2`   | `7`    |
# | `-`      | Subtract            | `5-2`   | `3`    |
# | `*`      | Multiply            | `5*2`   | `10`   |
# | `/`      | Division (float)    | `5/2`   | `2.5`  |
# | `//`     | Floor division      | `5//2`  | `2`    |
# | `%`      | Modulus (remainder) | `5%2`   | `1`    |
# | `**`     | Power               | `2**3`  | `8`    |

# %% [markdown]
# ### Assigment operators
# | Operator | Meaning               |
# | -------- | --------------------- |
# | `=`      | assign                |
# | `+=`     | add & assign          |
# | `-=`     | subtract & assign     |
# | `*=`     | multiply & assign     |
# | `/=`     | divide & assign       |
# | `//=`    | floor divide & assign |
# | `%=`     | remainder & assign    |
# | `**=`    | power & assign        |

# %%
x = 5
x = x + 5
print(x)
x = 5
# is same as 

x += 5
print(x)
# Out:
# 10
# 10

# %% [markdown]
# ### Comparison Operators
# | Operator | Meaning          |
# | -------- | ---------------- |
# | `==`     | equal            |
# | `!=`     | not equal        |
# | `>`      | greater          |
# | `<`      | less             |
# | `>=`     | greater or equal |
# | `<=`     | less or equal    |

# %% [markdown]
# **Precedence (important)**
# 2 + 3 * 4 = 14
# (2 + 3) * 4 = 20
