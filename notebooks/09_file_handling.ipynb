# %% [markdown]
# # File Handling
#
# This notebook covers file operations in Python:
# - Opening and closing files
# - Reading files
# - Writing files
# - File paths
# - Working with different file formats
