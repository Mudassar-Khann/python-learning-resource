# %% [markdown]
# # Modules and Packages
#
# This notebook covers modules and packages:
# - Importing modules
# - Creating modules
# - Package structure
# - Standard library modules
# - Third-party packages
